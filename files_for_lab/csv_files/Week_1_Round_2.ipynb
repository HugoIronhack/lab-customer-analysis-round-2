# %%
# Here are some libraries that we'll use

import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv')

# %%
# 1 Show the dataframe shape.

# %%
file1.head(1)
# Out:
#    unnamed:_0 customer    state  customer_lifetime_value response coverage  \
# 0           0  DK49336  Arizona               4809.21696       No    Basic
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College           2/18/11         Employed      M  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent               292.8  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
#
# [1 rows x 26 columns]

# %%
file1.shape
# Out:
# (10910, 26)

# %%
# 2 Standardize header names.

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in file1.columns]

# %%
cols
# Out:
# ['unnamed:_0',
#  'customer',
#  'state',
#  'customer_lifetime_value',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'total_claim_amount',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
file1.columns = cols

# %%
file1.head(1)
# Out:
#    unnamed:_0 customer    state  customer_lifetime_value response coverage  \
# 0           0  DK49336  Arizona               4809.21696       No    Basic
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College           2/18/11         Employed      M  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer3          Agent               292.8  Four-Door Car
#
#   vehicle_size vehicle_type
# 0      Medsize          NaN
#
# [1 rows x 26 columns]

# %%
# 3 Which columns are numerical?  #this time I create a list filled by the numerical column

# %%
num_cols = file1.select_dtypes(include=['int', 'float']).columns.tolist()

# %%
num_cols
# Out:
# ['unnamed:_0',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'total_claim_amount']

# %%
# 4 Which columns are categorical?

# %%
cat_cols = file1.select_dtypes(include=['object']).columns.tolist()

# %%
cat_cols
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
# 5 Check and deal with NaN values.

# %%
file1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
data=file1.dropna()

# %%
data
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
#Datetime format - Extract the months from the dataset and store in a separate column.
#Then filter the data to show only the information for the first quarter , ie. January, February and March.
#Hint: If data from March does not exist, consider only January and February.

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date']) 


data['month'] = data['effective_to_date'].dt.month


first_quarter = data[(data['month'] <= 3)]
# Out:
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_62768/4247534700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_62768/4247534700.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['month'] = data['effective_to_date'].dt.month

# %%
first_quarter
# Out:
#       unnamed:_0 customer       state customer_lifetime_value response  \
# 2              2  LZ68649  Washington              14947.9173       No
# 3              3  XL78013      Oregon             22332.43946      Yes
# 10            10  HG93801     Arizona             5154.764074       No
# 13            13  KR82385  California             5454.587929       No
# 16            16  FH51383  California             5326.677654       No
# ...          ...      ...         ...                     ...      ...
# 10902      10902  PP30874  California             3579.023825       No
# 10903      10903  SU71163     Arizona             2771.663013       No
# 10904      10904  QI63521      Nevada             19228.46362       No
# 10906      10906  KX53892      Oregon             5259.444853       No
# 10908      10908  WA60547  California             11971.97765       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
# BONUS: Put all the previously mentioned data transformations into a function.

# %%
def first_quarter(data, effective_to_date):
    data[effective_to_date] = pd.to_datetime(data[effective_to_date])
    data['month'] = data[effective_to_date].dt.month
    first_quarter = data[data['month'].isin([1, 2, 3])]
    return first_quarter

# %%
first_quarter_data = first_quarter(data, 'effective_to_date')
# Out:
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_62768/2843132616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[effective_to_date] = pd.to_datetime(data[effective_to_date])
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_62768/2843132616.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['month'] = data[effective_to_date].dt.month

# %%
first_quarter_data
# Out:
#       unnamed:_0 customer       state customer_lifetime_value response  \
# 2              2  LZ68649  Washington              14947.9173       No
# 3              3  XL78013      Oregon             22332.43946      Yes
# 10            10  HG93801     Arizona             5154.764074       No
# 13            13  KR82385  California             5454.587929       No
# 16            16  FH51383  California             5326.677654       No
# ...          ...      ...         ...                     ...      ...
# 10902      10902  PP30874  California             3579.023825       No
# 10903      10903  SU71163     Arizona             2771.663013       No
# 10904      10904  QI63521      Nevada             19228.46362       No
# 10906      10906  KX53892      Oregon             5259.444853       No
# 10908      10908  WA60547  California             11971.97765       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...
